# %%
import pickle
from model.network import train, test
from data_process import load_dataset
from product_analysis import gen_product_embedding


def prepare_data():

    """
    处理训练数据
    :return:
    """

    trainset = load_dataset('data/train_data.txt')
    testset = load_dataset('data/test_data.txt')

    print("Finished Loading Dataset")

    #构建一个用户特征dict，这个特征将会作为模型的输入，将所有用户的特征构建成一个key为用户id的dict返回
    user_file = open("data/user_dict.pkl",'rb')
    user_dict = pickle.load(user_file)
    user_file.close()
    print("Finished Loading User Dict")

    product_file = open("data/product_dict.pkl","rb")
    product_dict = pickle.load(product_file)
    product_file.close()
    print("Finished Loading Product Dict")

    return trainset, testset, user_dict, product_dict

# %%
trainset, testset, user_dict, product_dict = prepare_data()
embedding_method = gen_product_embedding
# Out:
# Finished Loading Dataset
# Finished Loading User Dict
# Finished Loading Product Dict

# %%
train(trainset, epoch=10, user_feature=user_dict, product_feature=product_dict, embedding=embedding_method)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-430ba99aa17e> in <module>()
# ----> 1 train(trainset, epoch=10, user_feature=user_dict, product_feature=product_dict, embedding=embedding_method)
#
# /Users/Vic/Dev/MachineLearning/Seedcup2017/PurchasePrediction/model/network.pyc in train(trainset, epoch, user_feature, product_feature, embedding)
#     141                 user_desc_vector,
#     142                 product_self_vector,
# --> 143                 product_desc_vector
#     144             )
#     145             loss = loss_criterion(prob, label)
#
# /Users/Vic/Dev/MachineLearning/Seedcup2017/PurchasePrediction/model/network.pyc in output(network, user_self_vector, user_desc_vector, product_self_vector, product_desc_vector)
#     101         user_vector=user_self_vector,
#     102         user_desc_vector=user_desc_vector,
# --> 103         product_desc_vector=product_desc_vector
#     104     )
#     105
#
# /Library/Python/2.7/site-packages/torch/nn/modules/module.pyc in __call__(self, *input, **kwargs)
#     222         for hook in self._forward_pre_hooks.values():
#     223             hook(self, input)
# --> 224         result = self.forward(*input, **kwargs)
#     225         for hook in self._forward_hooks.values():
#     226             hook_result = hook(self, input, result)
#
# /Users/Vic/Dev/MachineLearning/Seedcup2017/PurchasePrediction/model/network.pyc in forward(self, product_vector, user_vector, user_desc_vector, product_desc_vector)
#      42
#      43         user_desc = F.relu(self.user_merchandise_layer(user_desc_vector))
# ---> 44         user_self = F.relu(self.user_self_layer(user_vector))
#      45         merchandise_desc = F.relu(self.merchandise_description_layer(product_desc_vector))
#      46         merchandise_self = F.relu(self.merchandise_self_layer(product_vector))
#
# /Library/Python/2.7/site-packages/torch/nn/modules/module.pyc in __call__(self, *input, **kwargs)
#     222         for hook in self._forward_pre_hooks.values():
#     223             hook(self, input)
# --> 224         result = self.forward(*input, **kwargs)
#     225         for hook in self._forward_hooks.values():
#     226             hook_result = hook(self, input, result)
#
# /Library/Python/2.7/site-packages/torch/nn/modules/linear.pyc in forward(self, input)
#      51
#      52     def forward(self, input):
# ---> 53         return F.linear(input, self.weight, self.bias)
#      54
#      55     def __repr__(self):
#
# /Library/Python/2.7/site-packages/torch/nn/functional.pyc in linear(input, weight, bias)
#     553         return torch.addmm(bias, input, weight.t())
#     554
# --> 555     output = input.matmul(weight.t())
#     556     if bias is not None:
#     557         output += bias
#
# /Library/Python/2.7/site-packages/torch/autograd/variable.pyc in matmul(self, other)
#     558
#     559     def matmul(self, other):
# --> 560         return torch.matmul(self, other)
#     561
#     562     @staticmethod
#
# /Library/Python/2.7/site-packages/torch/functional.pyc in matmul(tensor1, tensor2, out)
#     166     elif dim_tensor1 == 1 and dim_tensor2 == 2:
#     167         if out is None:
# --> 168             return torch.mm(tensor1.unsqueeze(0), tensor2).squeeze_(0)
#     169         else:
#     170             return torch.mm(tensor1.unsqueeze(0), tensor2, out=out).squeeze_(0)
#
# /Library/Python/2.7/site-packages/torch/autograd/variable.pyc in mm(self, matrix)
#     577     def mm(self, matrix):
#     578         output = Variable(self.data.new(self.data.size(0), matrix.data.size(1)))
# --> 579         return Addmm.apply(output, self, matrix, 0, 1, True)
#     580
#     581     def bmm(self, batch):
#
# /Library/Python/2.7/site-packages/torch/autograd/_functions/blas.pyc in forward(ctx, add_matrix, matrix1, matrix2, alpha, beta, inplace)
#      24         output = _get_output(ctx, add_matrix, inplace=inplace)
#      25         return torch.addmm(alpha, add_matrix, beta,
# ---> 26                            matrix1, matrix2, out=output)
#      27
#      28     @staticmethod
#
# RuntimeError: size mismatch, m1: [1 x 9], m2: [10 x 128] at /Users/soumith/code/builder/wheel/pytorch-src/torch/lib/TH/generic/THTensorMath.c:1293

# %%
from model.network import train, test

# %%
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-430ba99aa17e> in <module>()
# ----> 1 train(trainset, epoch=10, user_feature=user_dict, product_feature=product_dict, embedding=embedding_method)
#
# /Users/Vic/Dev/MachineLearning/Seedcup2017/PurchasePrediction/model/network.pyc in train(trainset, epoch, user_feature, product_feature, embedding)
#     141                 user_desc_vector,
#     142                 product_self_vector,
# --> 143                 product_desc_vector
#     144             )
#     145             loss = loss_criterion(prob, label)
#
# /Users/Vic/Dev/MachineLearning/Seedcup2017/PurchasePrediction/model/network.pyc in output(network, user_self_vector, user_desc_vector, product_self_vector, product_desc_vector)
#     101         user_vector=user_self_vector,
#     102         user_desc_vector=user_desc_vector,
# --> 103         product_desc_vector=product_desc_vector
#     104     )
#     105
#
# /Library/Python/2.7/site-packages/torch/nn/modules/module.pyc in __call__(self, *input, **kwargs)
#     222         for hook in self._forward_pre_hooks.values():
#     223             hook(self, input)
# --> 224         result = self.forward(*input, **kwargs)
#     225         for hook in self._forward_hooks.values():
#     226             hook_result = hook(self, input, result)
#
# /Users/Vic/Dev/MachineLearning/Seedcup2017/PurchasePrediction/model/network.pyc in forward(self, product_vector, user_vector, user_desc_vector, product_desc_vector)
#      42
#      43         user_desc = F.relu(self.user_merchandise_layer(user_desc_vector))
# ---> 44         user_self = F.relu(self.user_self_layer(user_vector))
#      45         merchandise_desc = F.relu(self.merchandise_description_layer(product_desc_vector))
#      46         merchandise_self = F.relu(self.merchandise_self_layer(product_vector))
#
# /Library/Python/2.7/site-packages/torch/nn/modules/module.pyc in __call__(self, *input, **kwargs)
#     222         for hook in self._forward_pre_hooks.values():
#     223             hook(self, input)
# --> 224         result = self.forward(*input, **kwargs)
#     225         for hook in self._forward_hooks.values():
#     226             hook_result = hook(self, input, result)
#
# /Library/Python/2.7/site-packages/torch/nn/modules/linear.pyc in forward(self, input)
#      51
#      52     def forward(self, input):
# ---> 53         return F.linear(input, self.weight, self.bias)
#      54
#      55     def __repr__(self):
#
# /Library/Python/2.7/site-packages/torch/nn/functional.pyc in linear(input, weight, bias)
#     553         return torch.addmm(bias, input, weight.t())
#     554
# --> 555     output = input.matmul(weight.t())
#     556     if bias is not None:
#     557         output += bias
#
# /Library/Python/2.7/site-packages/torch/autograd/variable.pyc in matmul(self, other)
#     558
#     559     def matmul(self, other):
# --> 560         return torch.matmul(self, other)
#     561
#     562     @staticmethod
#
# /Library/Python/2.7/site-packages/torch/functional.pyc in matmul(tensor1, tensor2, out)
#     166     elif dim_tensor1 == 1 and dim_tensor2 == 2:
#     167         if out is None:
# --> 168             return torch.mm(tensor1.unsqueeze(0), tensor2).squeeze_(0)
#     169         else:
#     170             return torch.mm(tensor1.unsqueeze(0), tensor2, out=out).squeeze_(0)
#
# /Library/Python/2.7/site-packages/torch/autograd/variable.pyc in mm(self, matrix)
#     577     def mm(self, matrix):
#     578         output = Variable(self.data.new(self.data.size(0), matrix.data.size(1)))
# --> 579         return Addmm.apply(output, self, matrix, 0, 1, True)
#     580
#     581     def bmm(self, batch):
#
# /Library/Python/2.7/site-packages/torch/autograd/_functions/blas.pyc in forward(ctx, add_matrix, matrix1, matrix2, alpha, beta, inplace)
#      24         output = _get_output(ctx, add_matrix, inplace=inplace)
#      25         return torch.addmm(alpha, add_matrix, beta,
# ---> 26                            matrix1, matrix2, out=output)
#      27
#      28     @staticmethod
#
# RuntimeError: size mismatch, m1: [1 x 9], m2: [10 x 128] at /Users/soumith/code/builder/wheel/pytorch-src/torch/lib/TH/generic/THTensorMath.c:1293

# %%
del train
del test

# %%
train(trainset, epoch=10, user_feature=user_dict, product_feature=product_dict, embedding=embedding_method)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-430ba99aa17e> in <module>()
# ----> 1 train(trainset, epoch=10, user_feature=user_dict, product_feature=product_dict, embedding=embedding_method)
#
# NameError: name 'train' is not defined

# %%
from model.network import train, test

# %%
train(trainset, epoch=10, user_feature=user_dict, product_feature=product_dict, embedding=embedding_method)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-9-430ba99aa17e> in <module>()
# ----> 1 train(trainset, epoch=10, user_feature=user_dict, product_feature=product_dict, embedding=embedding_method)
#
# /Users/Vic/Dev/MachineLearning/Seedcup2017/PurchasePrediction/model/network.pyc in train(trainset, epoch, user_feature, product_feature, embedding)
#     141                 user_desc_vector,
#     142                 product_self_vector,
# --> 143                 product_desc_vector
#     144             )
#     145             loss = loss_criterion(prob, label)
#
# /Users/Vic/Dev/MachineLearning/Seedcup2017/PurchasePrediction/model/network.pyc in output(network, user_self_vector, user_desc_vector, product_self_vector, product_desc_vector)
#     101         user_vector=user_self_vector,
#     102         user_desc_vector=user_desc_vector,
# --> 103         product_desc_vector=product_desc_vector
#     104     )
#     105
#
# /Library/Python/2.7/site-packages/torch/nn/modules/module.pyc in __call__(self, *input, **kwargs)
#     222         for hook in self._forward_pre_hooks.values():
#     223             hook(self, input)
# --> 224         result = self.forward(*input, **kwargs)
#     225         for hook in self._forward_hooks.values():
#     226             hook_result = hook(self, input, result)
#
# /Users/Vic/Dev/MachineLearning/Seedcup2017/PurchasePrediction/model/network.pyc in forward(self, product_vector, user_vector, user_desc_vector, product_desc_vector)
#      42
#      43         user_desc = F.relu(self.user_merchandise_layer(user_desc_vector))
# ---> 44         user_self = F.relu(self.user_self_layer(user_vector))
#      45         merchandise_desc = F.relu(self.merchandise_description_layer(product_desc_vector))
#      46         merchandise_self = F.relu(self.merchandise_self_layer(product_vector))
#
# /Library/Python/2.7/site-packages/torch/nn/modules/module.pyc in __call__(self, *input, **kwargs)
#     222         for hook in self._forward_pre_hooks.values():
#     223             hook(self, input)
# --> 224         result = self.forward(*input, **kwargs)
#     225         for hook in self._forward_hooks.values():
#     226             hook_result = hook(self, input, result)
#
# /Library/Python/2.7/site-packages/torch/nn/modules/linear.pyc in forward(self, input)
#      51
#      52     def forward(self, input):
# ---> 53         return F.linear(input, self.weight, self.bias)
#      54
#      55     def __repr__(self):
#
# /Library/Python/2.7/site-packages/torch/nn/functional.pyc in linear(input, weight, bias)
#     553         return torch.addmm(bias, input, weight.t())
#     554
# --> 555     output = input.matmul(weight.t())
#     556     if bias is not None:
#     557         output += bias
#
# /Library/Python/2.7/site-packages/torch/autograd/variable.pyc in matmul(self, other)
#     558
#     559     def matmul(self, other):
# --> 560         return torch.matmul(self, other)
#     561
#     562     @staticmethod
#
# /Library/Python/2.7/site-packages/torch/functional.pyc in matmul(tensor1, tensor2, out)
#     166     elif dim_tensor1 == 1 and dim_tensor2 == 2:
#     167         if out is None:
# --> 168             return torch.mm(tensor1.unsqueeze(0), tensor2).squeeze_(0)
#     169         else:
#     170             return torch.mm(tensor1.unsqueeze(0), tensor2, out=out).squeeze_(0)
#
# /Library/Python/2.7/site-packages/torch/autograd/variable.pyc in mm(self, matrix)
#     577     def mm(self, matrix):
#     578         output = Variable(self.data.new(self.data.size(0), matrix.data.size(1)))
# --> 579         return Addmm.apply(output, self, matrix, 0, 1, True)
#     580
#     581     def bmm(self, batch):
#
# /Library/Python/2.7/site-packages/torch/autograd/_functions/blas.pyc in forward(ctx, add_matrix, matrix1, matrix2, alpha, beta, inplace)
#      24         output = _get_output(ctx, add_matrix, inplace=inplace)
#      25         return torch.addmm(alpha, add_matrix, beta,
# ---> 26                            matrix1, matrix2, out=output)
#      27
#      28     @staticmethod
#
# RuntimeError: size mismatch, m1: [1 x 9], m2: [10 x 128] at /Users/soumith/code/builder/wheel/pytorch-src/torch/lib/TH/generic/THTensorMath.c:1293

# %%
train(trainset, epoch=10, user_feature=user_dict, product_feature=product_dict, embedding=embedding_method)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-430ba99aa17e> in <module>()
# ----> 1 train(trainset, epoch=10, user_feature=user_dict, product_feature=product_dict, embedding=embedding_method)
#
# /Users/Vic/Dev/MachineLearning/Seedcup2017/PurchasePrediction/model/network.pyc in train(trainset, epoch, user_feature, product_feature, embedding)
#     141                 user_desc_vector,
#     142                 product_self_vector,
# --> 143                 product_desc_vector
#     144             )
#     145             loss = loss_criterion(prob, label)
#
# /Users/Vic/Dev/MachineLearning/Seedcup2017/PurchasePrediction/model/network.pyc in output(network, user_self_vector, user_desc_vector, product_self_vector, product_desc_vector)
#     101         user_vector=user_self_vector,
#     102         user_desc_vector=user_desc_vector,
# --> 103         product_desc_vector=product_desc_vector
#     104     )
#     105
#
# /Library/Python/2.7/site-packages/torch/nn/modules/module.pyc in __call__(self, *input, **kwargs)
#     222         for hook in self._forward_pre_hooks.values():
#     223             hook(self, input)
# --> 224         result = self.forward(*input, **kwargs)
#     225         for hook in self._forward_hooks.values():
#     226             hook_result = hook(self, input, result)
#
# /Users/Vic/Dev/MachineLearning/Seedcup2017/PurchasePrediction/model/network.pyc in forward(self, product_vector, user_vector, user_desc_vector, product_desc_vector)
#      42
#      43         user_desc = F.relu(self.user_merchandise_layer(user_desc_vector))
# ---> 44         user_self = F.relu(self.user_self_layer(user_vector))
#      45         merchandise_desc = F.relu(self.merchandise_description_layer(product_desc_vector))
#      46         merchandise_self = F.relu(self.merchandise_self_layer(product_vector))
#
# /Library/Python/2.7/site-packages/torch/nn/modules/module.pyc in __call__(self, *input, **kwargs)
#     222         for hook in self._forward_pre_hooks.values():
#     223             hook(self, input)
# --> 224         result = self.forward(*input, **kwargs)
#     225         for hook in self._forward_hooks.values():
#     226             hook_result = hook(self, input, result)
#
# /Library/Python/2.7/site-packages/torch/nn/modules/linear.pyc in forward(self, input)
#      51
#      52     def forward(self, input):
# ---> 53         return F.linear(input, self.weight, self.bias)
#      54
#      55     def __repr__(self):
#
# /Library/Python/2.7/site-packages/torch/nn/functional.pyc in linear(input, weight, bias)
#     553         return torch.addmm(bias, input, weight.t())
#     554
# --> 555     output = input.matmul(weight.t())
#     556     if bias is not None:
#     557         output += bias
#
# /Library/Python/2.7/site-packages/torch/autograd/variable.pyc in matmul(self, other)
#     558
#     559     def matmul(self, other):
# --> 560         return torch.matmul(self, other)
#     561
#     562     @staticmethod
#
# /Library/Python/2.7/site-packages/torch/functional.pyc in matmul(tensor1, tensor2, out)
#     166     elif dim_tensor1 == 1 and dim_tensor2 == 2:
#     167         if out is None:
# --> 168             return torch.mm(tensor1.unsqueeze(0), tensor2).squeeze_(0)
#     169         else:
#     170             return torch.mm(tensor1.unsqueeze(0), tensor2, out=out).squeeze_(0)
#
# /Library/Python/2.7/site-packages/torch/autograd/variable.pyc in mm(self, matrix)
#     577     def mm(self, matrix):
#     578         output = Variable(self.data.new(self.data.size(0), matrix.data.size(1)))
# --> 579         return Addmm.apply(output, self, matrix, 0, 1, True)
#     580
#     581     def bmm(self, batch):
#
# /Library/Python/2.7/site-packages/torch/autograd/_functions/blas.pyc in forward(ctx, add_matrix, matrix1, matrix2, alpha, beta, inplace)
#      24         output = _get_output(ctx, add_matrix, inplace=inplace)
#      25         return torch.addmm(alpha, add_matrix, beta,
# ---> 26                            matrix1, matrix2, out=output)
#      27
#      28     @staticmethod
#
# RuntimeError: size mismatch, m1: [1 x 9], m2: [10 x 128] at /Users/soumith/code/builder/wheel/pytorch-src/torch/lib/TH/generic/THTensorMath.c:1293
